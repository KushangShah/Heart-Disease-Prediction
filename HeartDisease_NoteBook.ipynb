# %% [markdown]
# <h1 align="center">
#   <span>Project</span>
#   <span>Name</span>
#   <span>-</span>
#   <span>Heart</span>
#   <span>Disease</span>
#   <span>Prediction</span>
#   <span>.</span>
# </h1>
#
# <style>
#     h1 {
#         text-align: center;
#         color: #DFBBB1;
#         padding: 50px;
#         border-radius: 12px;
#         display: inline-block;
#         background: linear-gradient(90deg, #5E4352, #BE3E82, #E43F6F, #F56476);
#         background-size: 200% 200%;
#         transition: background-position 0.6s ease, transform 0.4s ease;
#         cursor: pointer;
#     }
#
#     h1 span {
#         opacity: 0.3;
#         display: inline-block;
#         transform: translateY(20px);
#         transition: opacity 0.4s ease, transform 0.4s ease;
#     }
#
#     h1:hover {
#         background-position: 100% 0;
#         transform: scale(1.05);
#     }
#
#     /* Staggered reveal effect */
#     h1:hover span {
#         opacity: 1;
#         transform: translateY(0);
#     }
#
#     h1:hover span:nth-child(1) { transition-delay: 0s; }
#     h1:hover span:nth-child(2) { transition-delay: 0.2s; }
#     h1:hover span:nth-child(3) { transition-delay: 0.4s; }
#     h1:hover span:nth-child(4) { transition-delay: 0.6s; }
#     h1:hover span:nth-child(5) { transition-delay: 0.8s; }
#     h1:hover span:nth-child(6) { transition-delay: 1.0s; }
#     h1:hover span:nth-child(7) { transition-delay: 1.2s; }
# </style>

# %% [markdown]
# ##### **Project Type**    - EDA/Classification
# ##### **Contribution**    - Individual
# ##### **Member Name-** Kushang shah

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# <h3 id="summary" tabindex="0" aria-label="Project summary">
#   <span class="line">❤️ <b>Project:</b> Predicting Heart Disease using machine learning techniques.</span>
#   <span class="line">📊 We performed <b>Exploratory Data Analysis (EDA)</b> to understand the dataset and detect any data quality issues.</span>
#   <span class="line">🧹 <b>Data Cleaning:</b> Removed duplicates and handled missing or inconsistent records for better model reliability.</span>
#   <span class="line">📈 <b>Visualization:</b> Explored key health indicators and their relationship with heart disease risk.</span>
#   <span class="line">🧠 <b>Model Building:</b> Trained and evaluated several ML models — Logistic Regression, KNN, SVM, Decision Tree, Random Forest, and XGBoost.</span>
#   <span class="line">⚙️ <b>Optimization:</b> Used cross-validation and hyperparameter tuning to improve performance and generalization.</span>
#   <span class="line">🏆 <b>Best Model:</b> The <b>K-Nearest Neighbors (KNN)</b> model achieved the best results and was saved for potential deployment.</span>
#   <span class="line">🔍 <b>Feature Importance:</b> Key health indicators influencing predictions were identified and analyzed for interpretability.</span>
#   <span class="line">🏢 <i>This project is developed as part of the Machine Learning program by <b>Unified Mentor Private Limited</b>.</i></span>
# </h3>
#
# <style>
#   #summary {
#     display: inline-block;
#     max-width: 950px;
#     text-align: left;
#     color: #ffffffff;
#     background: #000000ff;
#     border: 1px solid #000000ff;
#     padding: 20px 24px;
#     border-radius: 10px;
#     cursor: pointer;
#     line-height: 1.6;
#     font-family: system-ui, -apple-system, "Segoe UI", Roboto, "Helvetica Neue", Arial;
#     font-size: 0.98rem;
#     transition: transform 0.18s ease;
#     outline: none;
#   }
#
#   #summary:focus {
#     box-shadow: 0 0 0 4px rgba(0,0,0,0.04);
#   }
#
#   .line {
#     display: block;
#     opacity: 0.5;
#     transform: translateY(8px);
#     transition: opacity 360ms cubic-bezier(.2,.9,.2,1),
#                 transform 360ms cubic-bezier(.2,.9,.2,1);
#     margin-bottom: 0.6em;
#   }
#
#   #summary:hover .line,
#   #summary:focus .line {
#     opacity: 1;
#     transform: translateY(0);
#   }
#
#   #summary .line:nth-of-type(1) { transition-delay: 0.00s; }
#   #summary .line:nth-of-type(2) { transition-delay: 0.06s; }
#   #summary .line:nth-of-type(3) { transition-delay: 0.12s; }
#   #summary .line:nth-of-type(4) { transition-delay: 0.18s; }
#   #summary .line:nth-of-type(5) { transition-delay: 0.24s; }
#   #summary .line:nth-of-type(6) { transition-delay: 0.30s; }
#   #summary .line:nth-of-type(7) { transition-delay: 0.36s; }
#   #summary .line:nth-of-type(8) { transition-delay: 0.42s; }
#   #summary .line:nth-of-type(9) { transition-delay: 0.48s; }
#   #summary .line:nth-of-

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# My GitHub Link [here](https://github.com/KushangShah/Heart-Disease-Prediction).
#
# PPT/PDF [here](https://drive.google.com/drive/folders/10WqsaHOfEQ0AnsEVjaxLkouV2LB3Aneo?usp=share_link).
#
# Video Presentation Link [here](https://drive.google.com/drive/folders/10WqsaHOfEQ0AnsEVjaxLkouV2LB3Aneo?usp=share_link).

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# <h3 id="summary" tabindex="0" aria-label="Heart Disease Prediction Objectives">
#   <span class="line"><b>Objective:</b> Heart disease is a major global health concern. Early and accurate prediction is crucial for timely intervention and improved patient outcomes.</span>
#   <span class="line">This project aims to build a <b>machine learning model</b> that predicts the likelihood of heart disease using common health indicators.</span>
#   <span class="line">The goal is to assist healthcare professionals in <b>risk assessment and diagnosis</b> through data-driven insights.</span>
#   <span class="line">1️⃣ Can we predict heart disease with high accuracy using readily available health data?</span>
#   <span class="line">2️⃣ Which health indicators are the strongest predictors of heart disease in this dataset?</span>
#   <span class="line">3️⃣ How do different machine learning models perform in predicting heart disease?</span>
#   <span class="line">4️⃣ Can we identify patterns in patient data that indicate a higher risk of heart disease?</span>
#   <span class="line">5️⃣ How can machine learning contribute to early diagnosis and prevention of heart disease?</span>
#   <span class="line">6️⃣ Is there a significant difference in heart disease prevalence between genders in this dataset?</span>
#   <span class="line">🏢 <i>This project is developed as part of the Machine Learning program by <b>Unified Mentor Private Limited</b>.</i></span>
# </h3>
#
# <style>
#   #summary {
#     display: inline-block;
#     max-width: 950px;
#     text-align: left;
#     color: #ffffffff;
#     background: #000000ff;
#     border: 1px solid #000000ff;
#     padding: 20px 24px;
#     border-radius: 10px;
#     cursor: pointer;
#     line-height: 1.6;
#     font-family: system-ui, -apple-system, "Segoe UI", Roboto, "Helvetica Neue", Arial;
#     font-size: 0.98rem;
#     transition: transform 0.18s ease;
#     outline: none;
#   }
#
#   #summary:focus {
#     box-shadow: 0 0 0 4px rgba(0,0,0,0.04);
#   }
#
#   .line {
#     display: block;
#     opacity: 0.5;
#     transform: translateY(8px);
#     transition: opacity 360ms cubic-bezier(.2,.9,.2,1),
#                 transform 360ms cubic-bezier(.2,.9,.2,1);
#     margin-bottom: 0.6em;
#   }
#
#   #summary:hover .line,
#   #summary:focus .line {
#     opacity: 1;
#     transform: translateY(0);
#   }
#
#   #summary .line:nth-of-type(1) { transition-delay: 0.00s; }
#   #summary .line:nth-of-type(2) { transition-delay: 0.06s; }
#   #summary .line:nth-of-type(3) { transition-delay: 0.12s; }
#   #summary .line:nth-of-type(4) { transition-delay: 0.18s; }
#   #summary .line:nth-of-type(5) { transition-delay: 0.24s; }
#   #summary .line:nth-of-type(6) { transition-delay: 0.30s; }
#   #summary .line:nth-of-type(7) { transition-delay: 0.36s; }
#   #summary .line:nth-of-type(8) { transition-delay: 0.42s; }
#   #summary .line:nth-of-type(9) { transition-delay: 0.48s; }
#   #summary .line:nth-of-type(10) { transition-delay: 0.54s; }
# </style>

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
from scipy import stats

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline 
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

from sklearn.linear_model import LogisticRegression 
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.svm import SVC 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.ensemble import RandomForestClassifier 
from xgboost import XGBClassifier

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
heart_disease_df = pd.read_csv("dataset.csv")
df = heart_disease_df.copy()

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
# 3   48    0                4           138          214                    0
# 4   54    1                3           150          195                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0
# 3            0             108                1      1.5         2       1
# 4            0             122                0      0.0         1       0

# %%
df.tail()
# Out:
#       age  sex  chest pain type  resting bp s  cholesterol  \
# 1185   45    1                1           110          264
# 1186   68    1                4           144          193
# 1187   57    1                4           130          131
# 1188   57    0                2           130          236
# 1189   38    1                3           138          175
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 1185                    0            0             132                0
# 1186                    1            0             141                0
# 1187                    0            0             115                1
# 1188                    0            2             174                0
# 1189                    0            0             173                0
#
#       oldpeak  ST slope  target
# 1185      1.2         2       1
# 1186      3.4         2       1
# 1187      1.2         2       1
# 1188      0.0         2       1
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print(f"Dataset:\n Num of Rows: {df.shape[0]}.\n Num of columns: {df.shape[1]}.")
# Out:
# Dataset:
#  Num of Rows: 1190.
#  Num of columns: 12.

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1190 entries, 0 to 1189
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  1190 non-null   int64
#  1   sex                  1190 non-null   int64
#  2   chest pain type      1190 non-null   int64
#  3   resting bp s         1190 non-null   int64
#  4   cholesterol          1190 non-null   int64
#  5   fasting blood sugar  1190 non-null   int64
#  6   resting ecg          1190 non-null   int64
#  7   max heart rate       1190 non-null   int64
#  8   exercise angina      1190 non-null   int64
#  9   oldpeak              1190 non-null   float64
#  10  ST slope             1190 non-null   int64
#  11  target               1190 non-null   int64
# dtypes: float64(1), int64(11)
# memory usage: 111.7 KB
# None

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
print(f"Number of duplicated values in the dataset: {df.duplicated().sum()}")

# dataset with droped duplicated values
new_df = df.copy()
new_df.drop_duplicates(inplace=True)
print(f"\nShape of new dataset after dropping duplicated values: {new_df.shape}")
# Out:
# Number of duplicated values in the dataset: 272
#
# Shape of new dataset after dropping duplicated values: (918, 12)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print("Dataset without droped duplicates")
display(df.isna().sum())
print("\ndataset with droped duplicates.")
display(new_df.isna().sum())
# Out:
# Dataset without droped duplicates
# age                    0
# sex                    0
# chest pain type        0
# resting bp s           0
# cholesterol            0
# fasting blood sugar    0
# resting ecg            0
# max heart rate         0
# exercise angina        0
# oldpeak                0
# ST slope               0
# target                 0
# dtype: int64
# dataset with droped duplicates.
# age                    0
# sex                    0
# chest pain type        0
# resting bp s           0
# cholesterol            0
# fasting blood sugar    0
# resting ecg            0
# max heart rate         0
# exercise angina        0
# oldpeak                0
# ST slope               0
# target                 0
# dtype: int64

# %%
# Visualizing the missing values
plt.style.use("dark_background")
sns.set_theme(style="darkgrid", rc={
    'axes.facecolor': "#4F5D75",      # plot area background
    'figure.facecolor': "#2D3142",    # whole figure background
    'axes.labelcolor': "white",
    'xtick.color': "white",
    'ytick.color': 'white',
    'text.color': "white",
    'axes.edgecolor': '#BFC0C0',
    'grid.color': '#EF8354'
})

plt.figure(figsize=(10,6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Values of original dataset")
plt.show()

plt.figure(figsize=(10,6))
sns.heatmap(new_df.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Values of droped dataset")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# - No missing values.
# - Dataset:
#     - Num of Rows: 1190.
#     - Num of columns: 12.
#
# - Duplicated values:
#     - 272

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
print("Columns in the dataset:")
for col in df.columns:
    print(f"- {col}")
# Out:
# Columns in the dataset:
# - age
# - sex
# - chest pain type
# - resting bp s
# - cholesterol
# - fasting blood sugar
# - resting ecg
# - max heart rate
# - exercise angina
# - oldpeak
# - ST slope
# - target

# %%
# Dataset Describe
print("Statistical Summary of the dataset:")
display(round(df.describe(), 2))
# Out:
# Statistical Summary of the dataset:
#            age      sex  chest pain type  resting bp s  cholesterol  \
# count  1190.00  1190.00          1190.00       1190.00      1190.00
# mean     53.72     0.76             3.23        132.15       210.36
# std       9.36     0.42             0.94         18.37       101.42
# min      28.00     0.00             1.00          0.00         0.00
# 25%      47.00     1.00             3.00        120.00       188.00
# 50%      54.00     1.00             4.00        130.00       229.00
# 75%      60.00     1.00             4.00        140.00       269.75
# max      77.00     1.00             4.00        200.00       603.00
#
#        fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# count              1190.00      1190.00         1190.00          1190.00
# mean                  0.21         0.70          139.73             0.39
# std                   0.41         0.87           25.52             0.49
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# <h3 id="summary" tabindex="0" aria-label="Project summary">
#     <span class="line">- age: Age of the patient.</span>
#     <span class="line">- sex: Gender of the patient. Values: 1 = male, 0 = female.</span>
#     <span class="line">- cp: Chest pain type. Values: 1 = Typical angina, 2 = Atypical angina, 3 = Non-anginal pain, 4 = Asymptomatic</span>
#     <span class="line">- resting bp s: Resting Blood Pressure (in mm Hg).</span>
#     <span class="line">- cholesterol: Serum Cholesterol level (in mg/dl).</span>
#     <span class="line">- Fasting blood sugar: > 120 mg/dl. Values: 1 = true, 0 = false.</span>
#     <span class="line">- resting ecg: Resting electrocardiographic results. Values: 0 = Normal, 1 = ST-T wave abnormality, 2 = Left ventricular hypertrophy.</span>
#     <span class="line">- max heart rate: Maximum heart rate achieved.</span>
#     <span class="line">- exercise angina: Exercise-induced angina. Values: 1 = yes, 0 = no.</span>
#     <span class="line">- oldpeak: ST depression induced by exercise relative to rest.</span>
#     <span class="line">- ST slope: Slope of the peak exercise ST segment. Values: 1 = Upward, 2 = flat, 3 = Downward.</span>
#     <span class="line">- target: Outcome variable (heart attack risk). Values: 1 = more chance of heart attack, 0 = less chance of heart attack.</span>
# </h3>
#
# <style>
#   /* container */
#   #summary {
#     display: inline-block;
#     max-width: 950px;
#     text-align: left;
#     color: #ffffffff;
#     background: #000000ff;           /* simple, plain background */
#     border: 1px solid #000000ff;
#     padding: 20px 24px;
#     border-radius: 10px;
#     cursor: pointer;
#     line-height: 1.6;
#     font-family: system-ui, -apple-system, "Segoe UI", Roboto, "Helvetica Neue", Arial;
#     font-size: 0.98rem;
#     transition: transform 0.18s ease;
#     outline: none;
#   }
#
#   /* keyboard focus visible */
#   #summary:focus {
#     box-shadow: 0 0 0 4px rgba(0,0,0,0.04);
#   }
#
#   /* each line-block */
#   .line {
#     display: block;                 /* force each span onto its own line */
#     opacity: 0.5;
#     transform: translateY(8px);
#     transition: opacity 360ms cubic-bezier(.2,.9,.2,1),
#                 transform 360ms cubic-bezier(.2,.9,.2,1);
#     margin-bottom: 0.6em;
#   }
#
#   /* reveal when hovered or focused (keyboard accessible) */
#   #summary:hover .line,
#   #summary:focus .line {
#     opacity: 1;
#     transform: translateY(0);
#   }
#
#   /* staggered delays (tweak increment to speed/slow the reveal) */
#     #summary .line:nth-of-type(1) { transition-delay: 0.00s; }
#     #summary .line:nth-of-type(2) { transition-delay: 0.06s; }
#     #summary .line:nth-of-type(3) { transition-delay: 0.12s; }
#     #summary .line:nth-of-type(4) { transition-delay: 0.18s; }
#     #summary .line:nth-of-type(5) { transition-delay: 0.24s; }
#     #summary .line:nth-of-type(6) { transition-delay: 0.30s; }
#     #summary .line:nth-of-type(7) { transition-delay: 0.36s; }
#     #summary .line:nth-of-type(8) { transition-delay: 0.42s; }
#     #summary .line:nth-of-type(9) { transition-delay: 0.48s; }
#     #summary .line:nth-of-type(10) { transition-delay: 0.54s; }
#     #summary .line:nth-of-type(11) { transition-delay: 0.60s; }
#     #summary .line:nth-of-type(12) { transition-delay: 0.66s; }
#     #summary .line:nth-of-type(13) { transition-delay: 0.72s; }
#     #summary .line:nth-of-type(14) { transition-delay: 0.78s; }
#     #summary .line:nth-of-type(15) { transition-delay: 0.84s; }
#     #summary .line:nth-of-type(16) { transition-delay: 0.90s; }
#     #summary .line:nth-of-type(17) { transition-delay: 0.96s; }
#     #summary .line:nth-of-type(18) { transition-delay: 1.02s; }
#     #summary .line:nth-of-type(19) { transition-delay: 1.08s; }
#     #summary .line:nth-of-type(20) { transition-delay: 1.14s; }
#     #summary .line:nth-of-type(21) { transition-delay: 1.20s; }
#     #summary .line:nth-of-type(22) { transition-delay: 1.26s; }
#     #summary .line:nth-of-type(23) { transition-delay: 1.32s; }
#     #summary .line:nth-of-type(24) { transition-delay: 1.38s; }
#     #summary .line:nth-of-type(25) { transition-delay: 1.44s; }
#     #summary .line:nth-of-type(26) { transition-delay: 1.50s; }
#     #summary .line:nth-of-type(27) { transition-delay: 1.56s; }
#     #summary .line:nth-of-type(28) { transition-delay: 1.62s; }
#     #summary .line:nth-of-type(29) { transition-delay: 1.68s; }
#     #summary .line:nth-of-type(30) { transition-delay: 1.74s; }
# </style>

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for col in df.columns:
    unique_values = df[col].unique()
    num_unique_values = len(unique_values)
    print(f"Column '{col}' has {num_unique_values} unique values: {unique_values}\n")
# Out:
# Column 'age' has 50 unique values: [40 49 37 48 54 39 45 58 42 38 43 60 36 44 53 52 51 56 41 32 65 35 59 50
#  47 31 46 57 55 63 66 34 33 61 29 62 28 30 74 68 72 64 69 67 73 70 77 75
#  76 71]
#
# Column 'sex' has 2 unique values: [1 0]
#
# Column 'chest pain type' has 4 unique values: [2 3 4 1]
#
# Column 'resting bp s' has 67 unique values: [140 160 130 138 150 120 110 136 115 100 124 113 125 145 112 132 118 170
#  142 190 135 180 108 155 128 106  92 200 122  98 105 133  95  80 137 185
#  165 126 152 116   0 144 154 134 104 139 131 141 178 146 158 123 102  96
#  143 172 156 114 127 101 174  94 148 117 192 129 164]
#
# Column 'cholesterol' has 222 unique values: [289 180 283 214 195 339 237 208 207 284 211 164 204 234 273 196 201 248
#  267 223 184 288 215 209 260 468 188 518 167 224 172 186 254 306 250 177
#  227 230 294 264 259 175 318 216 340 233 205 245 194 270 213 365 342 253
#  277 202 297 225 246 412 265 182 218 268 163 529 100 206 238 139 263 291
# ...

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1: Age Distribution

# %%
# Chart - 1 Age Distribution
plt.figure(figsize=(10, 5))
sns.histplot(df['age'], bins=30, kde=True, color="#919191", edgecolor='black', alpha=0.7)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Histogram with KDE is ideal to show the age distribution shape.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# That people between ~45 to ~65 are more than 25 to 45 and 65 to 80.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Highest chances of heart disease are seen in between the age of 45 to 65. Some people have have this problem earlier in their life and some could have after 65 making them more healthy!

# %% [markdown]
# #### Chart - 2: Gender Count

# %%
# Chart - 2 Gender Count (sex)
plt.figure(figsize=(10, 5))
sns.countplot(
    x='sex',
    data=df,
    hue='sex',
    palette=["#F355E1", "#317BFB"]
)

plt.title("Gender(Sex) count")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.xticks([0, 1], ["Female (0)", "Male (1)"])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Countplot (bar chart) is the straightforward way to show frequency of each gender(male and female).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# dataset have more males than females.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Chances of heart disease in male is more offen than female. Maybe due to smoking, drinking or any other bad habits.

# %% [markdown]
# #### Chart - 3: Distribution of Cholestrol

# %%
df['cholesterol']
# Out:
# 0       289
# 1       180
# 2       283
# 3       214
# 4       195
#        ...
# 1185    264
# 1186    193
# 1187    131
# 1188    236
# 1189    175
# Name: cholesterol, Length: 1190, dtype: int64

# %%
# Chart - 3 Distribution of Cholestrol
plt.figure(figsize=(10,5))
sns.histplot(
    df['cholesterol'],
    bins=30, 
    kde=True, 
    color="#919191", 
    edgecolor='black', 
    alpha=0.7
)

plt.title("Distribution of Cholestrol")
plt.xlabel("Cholestrol")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4: oldpeak

# %%
df['oldpeak']
# Out:
# 0       0.0
# 1       1.0
# 2       0.0
# 3       1.5
# 4       0.0
#        ...
# 1185    1.2
# 1186    3.4
# 1187    1.2
# 1188    0.0
# 1189    0.0
# Name: oldpeak, Length: 1190, dtype: float64

# %%
# Chart - 4 oldpeak

fig, ax = plt.subplots(1, 2, figsize=(12, 4))
sns.boxplot(x=df['oldpeak'], ax=ax[0], linecolor='#BFC0C0')
ax[0].set_title("Oldpeak Boxplot")
sns.histplot(df['oldpeak'], bins=30, kde=True, ax=ax[1])
ax[1].set_title("Oldpeak Distribution Histogram")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Oldpeak is an important clinical feature, boxplot and histogram show spread and abnormality of oldpeak.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# from the chart it is clear that many patients cluster near 0–2, with fewer high depression values and any heavy tails reveal severe cases.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes — patients with high oldpeak could be flagged for urgent follow-up, improving outcomes and efficient triage.

# %% [markdown]
# #### Chart - 5: Chest Pain type V/S Target.

# %%
# Chart - 5 Chest pain type V/S Target.
custom_color = {
    0: "#0193C3",
    1: "#C70000"
}

plt.figure(figsize=(8,5))
sns.countplot(
    x='chest pain type',
    hue='target',
    palette=custom_color,
    data=df
    )

plt.title("Chest Pain Type vs Heart Disease (target)")
plt.xlabel("Chest pain type")
plt.legend(title="Target", labels=['No disease (0)','Disease (1)'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Count plots show how disease prevalence varies across chest pain types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Certain chest pain types (e.g., type 2 or 3) may show higher proportions of target=1 — indicates predictive signal.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes — decision rules can prioritize patients with specific chest pain types for further tests.

# %% [markdown]
# #### Chart - 6: Cholesterol by Target

# %%
# Chart - 6 Cholesterol by Target
plt.figure(figsize=(8,5))

sns.boxplot(
    x='target',
    y='cholesterol',
    data=df,
    hue='target',
    palette=custom_color,
    linecolor='#BFC0C0'
    )

plt.xticks([0,1], ['No disease (0)','Disease (1)'])
plt.title("Cholesterol by Target")
plt.ylabel("Cholesterol (mg/dl)")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Box plot compares central tendency and spread of a numeric variable across two categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the graph it is clear that, disease group has higher median or more high-value outliers then cholesterol is a discriminating feature.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes — if cholesterol correlates strongly with disease, preventive cholesterol control programs can reduce disease incidence.

# %% [markdown]
# #### Chart - 7: Max Heart Rate Distribution by Target

# %%
# Chart - 7 Max Heart Rate Distribution by Target
plt.figure(figsize=(8,5))

sns.violinplot(
    x='target',
    y='max heart rate',
    data=df,
    inner='quartile',
    hue='target',
    palette=custom_color,
    linecolor='#BFC0C0'
    )

plt.xticks([0,1], ['No disease (0)','Disease (1)'])
plt.title("Max Heart Rate Distribution by Target")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Violin plot shows distribution shape and density across categories, more informative than a boxplot alone.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Disease vs non-disease groups have different HR distributions (e.g., disease group possibly lower max HR).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes — This can inform screening thresholds and exericise test interpretations.

# %% [markdown]
# #### Chart - 8: Avg V/S max heart rate.

# %%
# Chart - 8 Avg V/S max heart rate
plt.figure(figsize=(15,8))

sns.scatterplot(
    x='age',
    y='max heart rate',
    hue='target',
    data=df,
    alpha=0.7,
    
    )

plt.title("Age vs Max Heart Rate (colored by target)")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Scatterplots reveal relationships, trends, and clusters between two numeric variables and can show class separation when colored by target

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# negative trend may exist (older age → lower max heart rate). Separation patterns may show regions where disease is concentrated.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes — combining age and max HR can refine risk stratification for referrals/testing.

# %% [markdown]
# #### Chart - 9: Age V/S cholestrol

# %%
# Chart - 9 Jointplot Age V/S Cholestrol
# plt.figure(figsize=(10, 8))
sns.jointplot(
    x='age', 
    y='cholesterol',
    data=df,
    kind='hex',
    height=7,
    color='#919191',
    palette='viridis'
    )

plt.suptitle("Joint distribution: Age vs Cholesterol", y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Jointplot (hex) shows density of bivariate observations and marginal distributions — useful for spotting correlated clusters.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# May show clustering (e.g., older-high-chol cluster) — indicates correlated risk factors.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes — joint high-risk clusters can be targeted with combined interventions (lifestyle, meds).

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# Chart visualization code
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200, random_state=42)
X = df.drop('target', axis=1)
y = df['target']
rf.fit(X, y)
importances = pd.Series(rf.feature_importances_, index=X.columns).sort_values(ascending=False)

plt.figure(figsize=(8,5))
sns.barplot(x=importances.values, y=importances.index)
plt.title("Random Forest Feature Importances")
plt.xlabel("Importance")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Feature importance bar chart shows which features the tree ensemble relied on most — interpretable and actionable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Example: oldpeak, max heart rate, chest pain type often rank high — these are primary predictive drivers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes — focusing diagnostics and preventive programs on high-importance features improves cost-effectiveness.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
# Chart visualization code
from xgboost import XGBClassifier
xgb = XGBClassifier(n_estimators=200, learning_rate=0.05, max_depth=4, random_state=42, use_label_encoder=False, eval_metric='logloss')
xgb.fit(X, y)
importances_xgb = pd.Series(xgb.feature_importances_, index=X.columns).sort_values(ascending=False)

plt.figure(figsize=(8,5))
sns.barplot(x=importances_xgb.values, y=importances_xgb.index)
plt.title("XGBoost Feature Importances")
plt.xlabel("Importance")
plt.show()
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [17:56:29] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_abwcuua5oq/croot/xgboost-split_1749630928197/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Compare with RF importances to validate feature signals across model families (ensemble tree vs gradient boosting).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Consistency (or difference) in top features strengthens confidence; e.g., if both rank oldpeak high, it’s a robust predictor.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes — cross-model agreement increases trust in prioritized clinical measurements for resource allocation.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
# Chart visualization code
from pandas.plotting import parallel_coordinates
cols = ['age','resting bp s','cholesterol','max heart rate','oldpeak','target']
sample = df[cols].sample(n=300, random_state=42)  # sample for readability
plt.figure(figsize=(12,5))
parallel_coordinates(sample, 'target', cols=cols[:-1], alpha=0.6)
plt.title("Parallel Coordinates (sample of rows colored by target)")
plt.ylabel("Scaled values (varies by original scale)")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Parallel coordinates show multi-feature patterns for individual observations and highlight group-level differences across many features at once.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Disease vs nondisease show different multi-feature signature — e.g., disease lines may cluster with higher oldpeak and lower max HR.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes — helps build multi-feature screening rules for clinical triage rather than single-feature rules.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
# Chart visualization code
crosstab = pd.crosstab(df['chest pain type'], df['exercise angina'], normalize='index')
crosstab.plot(kind='bar', stacked=True, figsize=(8,5), colormap='Accent')
plt.legend(title='Exercise angina', labels=['No (0)', 'Yes (1)'])
plt.title("Proportion of Exercise Angina across Chest Pain Types")
plt.xlabel("Chest pain type")
plt.ylabel("Proportion")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Stacked (normalized) bar shows proportions of exercise angina within each chest pain category — reveals co-occurrence patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Some chest pain types may have higher rates of exercise-induced angina, suggesting more exercise-provoked pathology.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes — targeted exercise-stress testing for chest pain types with high angina rates can improve diagnostic yield and reduce unnecessary tests.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Chart visualization code
plt.figure(figsize=(10,8))
num_cols = ['age','resting bp s','cholesterol','max heart rate','oldpeak']
corr = df[num_cols + ['target']].corr()
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', center=0)
plt.title("Correlation Matrix (selected numeric features + target)")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Correlation heatmap succinctly shows pairwise linear relationships among numeric variables and with the target.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insights: e.g., oldpeak might have the strongest positive correlation with target, or max heart rate negative correlation — helps choose features.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
# Chart visualization code
sns.pairplot(df[['age','cholesterol','max heart rate','oldpeak','target']], hue='target', diag_kind='kde', height=2.4)
plt.suptitle("Pairplot (age, chol, max HR, oldpeak) by target", y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pairplot allows seeing bivariate relationships for multiple variable pairs and how classes separate across them.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Visual clusters and class separations across pairs (e.g., disease patients more likely high oldpeak and lower max HR).

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# ### Hypothetical Statement - 1: Association between Sex and Heart Disease

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# - **Null (H₀)**: There is no association between sex (male/female) and presence of heart disease.
# - **Alternative (H₁)**: There is an association between sex and presence of heart disease

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
contingency = pd.crosstab(df['sex'], df['target'])

# Perform Chi-square test
chi2, p, dof, expected = stats.chi2_contingency(contingency)
print("Chi-square Statistic:", chi2)
print("p-value:", p)

# interpretration of p value
alpha = 0.05
if p < alpha:
    print("Reject the null hypothesis: There is a significant association between sex and target.")
else:
    print("Fail to reject the null hypothesis: No significant association between sex and target.")
# Out:
# Chi-square Statistic: 113.83203133881408
# p-value: 1.4182782077111764e-26
# Reject the null hypothesis: There is a significant association between sex and target.

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# I used Chi-square test to check weather the distribution of one categorical variable differes depending on the other independent.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Since both variables(sex and target) are categorical, and knowing sex difference helps personalize programs and risk communication. But, Overemphasis could bias diagnosis if other factors (age, lifestyle) aren’t considered

# %% [markdown]
# ### Hypothetical Statement - 2: Difference in Mean Cholesterol between Disease and Non-Disease

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# - **Null (H₀)**: Mean cholesterol level is the same for people with and without heart disease.
# - **Alternative (H₁)**: Mean cholesterol levels differ between the two groups.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
chol_disease = df[df['target'] == 1]['cholesterol']
chol_no_disease = df[df['target'] == 0]['cholesterol']

# Perform independent t-test
t_stat, p_val = stats.ttest_ind(chol_disease, chol_no_disease, equal_var=False)
print("T-statistic:", t_stat)
print("p-value:", p_val)

# interpretation
alpha = 0.05
if p_val < alpha:
    print("Reject the null hypothesis: Mean cholesterol levels differ between the two groups.")
else:
    print("Fail to reject the null hypothesis: Mean cholesterol level is the same for people with and without heart disease.")
# Out:
# T-statistic: -7.174217814772026
# p-value: 1.3866276323115328e-12
# Reject the null hypothesis: Mean cholesterol levels differ between the two groups.

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# I performed t-test to check if two group means are significantly different.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# The dependent variable(cholestrol) is continuous and the grouping variable(target) is variable.
# cholesterol can be use as a key biomarker for early screening and preventive care. But If it is used as a sole indicator, may overlook cases driven by other risk factors (e.g., stress, genetics).

# %% [markdown]
# ### Hypothetical Statement - 3: Relationship between Age and Oldpeak (numerical vs numerical)

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# - **Null (H₀)**: There is no linear correlation between age and oldpeak.
# - **Alternative (H₁)**: There is a significant linear correlation between age and oldpeak

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
r_val, p_value = stats.pearsonr(df['age'], df['oldpeak'])
print("Correlation coefficient (r):", r_val)
print("p-value:", p_value)

# interpretation of p-value
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant linear correlation between age and oldpeak.")
else:
    print("Fail to reject the null hypothesis: No significant linear correlation between age and oldpeak.")
# Out:
# Correlation coefficient (r): 0.24509340522259754
# p-value: 9.729600759020264e-18
# Reject the null hypothesis: There is a significant linear correlation between age and oldpeak.

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# I used Pearson’s correlation to measures linear association and returns both correlation strength (r) and its significance (p-value).

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Both age and oldpeak are continuous and approximately normally distributed.
# which physiological pattern — older age linked with more ST depression, helping refine age-adjusted diagnostic thresholds. But older age linked with more ST depression, helping refine age-adjusted diagnostic thresholds.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.
# split the data into X and Y
X = df.drop('target', axis=1)
y = df['target']

# split the data in training and testing
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,      # 20% data for testing
    random_state=42,    # for reproducibility
    stratify=y
    )

# %%
print(f"Training set size: {X_train.shape} samples")    # Training size   (Rows, col) 
print(f"Testing set size: {X_test.shape} samples")      # Testing size    (Rows, col)  
print(f"Training set size: {y_train.shape} samples")    # Training size    
print(f"Testing set size: {y_test.shape} samples")      # Testing size
# Out:
# Training set size: (952, 11) samples
# Testing set size: (238, 11) samples
# Training set size: (952,) samples
# Testing set size: (238,) samples

# %%
# using scalar on train and test data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# I split the data into 20% testing and 80% traning the ML model. Followed by standardscaler for fine tuning train and test data for prediction ML model's performance.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1: Logistic Regression

# %%
import os
try:
    os.mkdir("metricx_insight")
except FileExistsError as e:
    print("File already exist to store metrics...")

# %%
# ML Model - 1 Logistic regression implementation
log_reg = LogisticRegression(random_state=42, max_iter=1000)

# Fit the Algorithm
log_reg.fit(X_train_scaled, y_train)

# Predict on the model
y_pred_scal = log_reg.predict(X_test_scaled)
y_proba_scal = log_reg.predict_proba(X_test_scaled)[:, 1]

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
metric_functions = {
    'accuracy': accuracy_score,
    'precision': precision_score,
    'recall': recall_score,
    'f1': f1_score,
    'roc_auc': roc_auc_score
}

# evaluation metrics
metrics = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc']

scal_evaluation_results = []

for metric in metrics:
    func = metric_functions[metric]  # getting the actual function
        
    if metric != "roc_auc":
        score = func(y_test, y_pred_scal)
    else:
        score = func(y_test, y_proba_scal)
    
    scal_evaluation_results.append({
        'Metric': metric,
        'Score': score
    })
        
display(scal_evaluation_results)

# plot the graph
metric_names = [result['Metric'] for result in scal_evaluation_results]
metric_scores = [result['Score'] for result in scal_evaluation_results]

plt.figure(figsize=(10,5))
sns.barplot(
    x=metric_names,
    y=metric_scores,
    hue=metric_names,
    palette='viridis'
    )

# Display mean values on bars
for i, v in enumerate(metric_scores):
    plt.text(i, v+0.01, f'{v:.3f}', ha='center', color='white', weight='bold', fontsize=10)

plt.title("Logistic Regression Evaluation Metrics")
plt.ylim(0, 1)
plt.ylabel("Score")
plt.show()
# Out:
# [{'Metric': 'accuracy', 'Score': 0.8403361344537815},
#  {'Metric': 'precision', 'Score': 0.84375},
#  {'Metric': 'recall', 'Score': 0.8571428571428571},
#  {'Metric': 'f1', 'Score': 0.8503937007874016},
#  {'Metric': 'roc_auc', 'Score': np.float64(0.9040532879818594)}]

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %% [markdown]
# ##### Cross - Validation

# %%
metrics = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc']

# Create an empty list to store results
log_reg_cross_val = []

# Cross-validation for each metric
log_reg = LogisticRegression(random_state=42, max_iter=1000)

for metric in metrics:
    cv_scores = cross_val_score(log_reg, X_train_scaled, y_train, cv=5, scoring=metric)
    mean_score = cv_scores.mean()
    
    # Print (optional)
    print(f"\nCross-validated {metric} scores: {cv_scores}")
    print(f"Logistic Regression - Mean CV {metric}: {mean_score:.4f}")
    
    # Store in list
    log_reg_cross_val.append({
        'Metric': metric,
        'Fold 1': cv_scores[0],
        'Fold 2': cv_scores[1],
        'Fold 3': cv_scores[2],
        'Fold 4': cv_scores[3],
        'Fold 5': cv_scores[4],
        'Mean': mean_score
    })

# Convert to DataFrame
log_reg_cv_df = pd.DataFrame(log_reg_cross_val)
display(log_reg_cv_df)
log_reg_cv_df.to_csv("metricx_insight/log_reg_cv_df.csv")
# Out:
# Cross-validated accuracy scores: [0.79057592 0.82722513 0.83157895 0.83684211 0.83684211]
# Logistic Regression - Mean CV accuracy: 0.8246
#
# Cross-validated precision scores: [0.7961165  0.88636364 0.83495146 0.87912088 0.82857143]
# Logistic Regression - Mean CV precision: 0.8450
#
# Cross-validated recall scores: [0.81188119 0.77227723 0.85148515 0.8        0.87      ]
# Logistic Regression - Mean CV recall: 0.8211
#
# Cross-validated f1 scores: [0.80392157 0.82539683 0.84313725 0.83769634 0.84878049]
# Logistic Regression - Mean CV f1: 0.8318
#
# Cross-validated roc_auc scores: [0.87755776 0.89548955 0.90721994 0.90266667 0.92222222]
# Logistic Regression - Mean CV roc_auc: 0.9010
#       Metric    Fold 1    Fold 2    Fold 3    Fold 4    Fold 5      Mean
# 0   accuracy  0.790576  0.827225  0.831579  0.836842  0.836842  0.824613
# 1  precision  0.796117  0.886364  0.834951  0.879121  0.828571  0.845025
# 2     recall  0.811881  0.772277  0.851485  0.800000  0.870000  0.821129
# ...

# %%
# Set figure size
plt.figure(figsize=(8, 5))

# Bar chart of mean CV scores
plt.bar(log_reg_cv_df['Metric'],
        log_reg_cv_df['Mean'],
        color='#2D3142',
        edgecolor='#BFC0C0'
        )

# Add labels and title
plt.title('Logistic Regression - Mean Cross-Validation Scores', fontsize=14)
plt.xlabel('Metric', fontsize=12)
plt.ylabel('Mean CV Score', fontsize=12)

# Display mean values on bars
for i, v in enumerate(log_reg_cv_df['Mean']):
    plt.text(i, v+0.01, f'{v:.3f}', ha='center', color='white', weight='bold', fontsize=10)

plt.ylim(0, 1)
plt.show()

# %% [markdown]
# ##### Hyperparameter Tunning

# %%
# hyperparameter tunning using gridseachCV
param_grid = {
    'C': [0.01, 0.1, 1, 10, 100],
    'penalty': ['l1', 'l2'],
    'solver': ['liblinear', 'saga']
}

# Create an empty list to store results
log_reg_ht_results = []

for metric in metrics:
    grid_log_reg = GridSearchCV(
        LogisticRegression(random_state=42, max_iter=1000),
        param_grid,
        scoring=metric,
        cv=5,
        n_jobs=-1
    )
    grid_log_reg.fit(X_train_scaled, y_train)
    
    mean_score = grid_log_reg.best_score_
    
    # Extract per-fold results
    fold_scores = [grid_log_reg.cv_results_[f'split{i}_test_score'].mean() for i in range(5)]
    
    print(f"\n===== Metric: {metric.upper()} =====")
    print("Best Parameters:", grid_log_reg.best_params_)
    # print(grid_log_reg)
    print("Best CV Mean Score:", round(mean_score, 4))
    
    log_reg_ht_results.append({
        'Metric': metric,
        'Fold 1': fold_scores[0],
        'Fold 2': fold_scores[1],
        'Fold 3': fold_scores[2],
        'Fold 4': fold_scores[3],
        'Fold 5': fold_scores[4],
        'Mean': mean_score
    })

log_reg_hyper_tunning_df = pd.DataFrame(log_reg_ht_results)
display(log_reg_hyper_tunning_df)
log_reg_hyper_tunning_df.to_csv("metricx_insight/log_reg_hyper_tunning_df.csv")
# Out:
# ===== Metric: ACCURACY =====
# Best Parameters: {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}
# Best CV Mean Score: 0.8288
#
# ===== Metric: PRECISION =====
# Best Parameters: {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}
# Best CV Mean Score: 0.85
#
# ===== Metric: RECALL =====
# Best Parameters: {'C': 0.01, 'penalty': 'l1', 'solver': 'saga'}
# Best CV Mean Score: 0.851
#
# ===== Metric: F1 =====
# Best Parameters: {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}
# Best CV Mean Score: 0.8352
#
# ===== Metric: ROC_AUC =====
# Best Parameters: {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}
# Best CV Mean Score: 0.9019
#       Metric    Fold 1    Fold 2    Fold 3    Fold 4    Fold 5      Mean
# 0   accuracy  0.791885  0.818325  0.827105  0.832895  0.839474  0.828829
# 1  precision  0.797560  0.871373  0.828718  0.872380  0.831039  0.850007
# 2     recall  0.812871  0.771782  0.850990  0.800500  0.872500  0.851030
# ...

# %%
# Set figure size
plt.figure(figsize=(8, 5))

# Bar chart of mean CV scores
plt.bar(log_reg_hyper_tunning_df['Metric'],
        log_reg_hyper_tunning_df['Mean'],
        color='#2D3142',
        edgecolor='#BFC0C0'
        )

# Add labels and title
plt.title('Logistic Regression - Hyperparameter Tunning', fontsize=14)
plt.xlabel('Metric', fontsize=12)
plt.ylabel('HT', fontsize=12)

# Display mean values on bars
for i, v in enumerate(log_reg_hyper_tunning_df['Mean']):
    plt.text(i, v+0.01, f'{v:.3f}', ha='center', color='white', weight='bold', fontsize=10)

plt.ylim(0, 1)
plt.show()

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# I used GridSearchCV for hyperparameter tuning. This method exhaustively searches through a specified parameter grid to find the best combination of hyperparameters for the model.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Yes, I observed slight improvements in some metrics after hyperparameter tuning for Logistic Regression. You can compare the "Mean CV Score" bar charts before and after tuning to see the specific changes for each metric (accuracy, precision, recall, f1, and ROC-AUC).

# %% [markdown]
# ### ML Model - 2: K - nearest neighbour (KNN)

# %%
# ML MODEL 2: KNN
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, y_train)

# predict
y_pred_knn = knn.predict(X_test_scaled)
y_proba_knn = knn.predict_proba(X_test_scaled)[:, 1]

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
knn_metric_functions = {
    'accuracy': accuracy_score,
    'precision': precision_score,
    'recall': recall_score,
    'f1': f1_score,
    'roc_auc': roc_auc_score
}

# evaluation metrics
metrics = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc']


knn_evaluation_results = []

for metric in metrics:
    func = knn_metric_functions[metric]  # getting the actual function
        
    if metric != "roc_auc":
        score = func(y_test, y_pred_knn)
    else:
        score = func(y_test, y_proba_knn)
    
    knn_evaluation_results.append({
        'Metric': metric,
        'Score': score
    })
        
display(knn_evaluation_results)

# plot the graph
metric_names = [result['Metric'] for result in knn_evaluation_results]
metric_scores = [result['Score'] for result in knn_evaluation_results]

plt.figure(figsize=(10,5))
sns.barplot(
    x=metric_names,
    y=metric_scores,
    hue=metric_names,
    palette='viridis'
    )

# Display mean values on bars
for i, v in enumerate(metric_scores):
    plt.text(i, v+0.01, f'{v:.3f}', ha='center', color='white', weight='bold', fontsize=10)

plt.title("KNN Evaluation Metrics")
plt.ylim(0, 1)
plt.ylabel("Score")
plt.show()
# Out:
# [{'Metric': 'accuracy', 'Score': 0.8361344537815126},
#  {'Metric': 'precision', 'Score': 0.8270676691729323},
#  {'Metric': 'recall', 'Score': 0.873015873015873},
#  {'Metric': 'f1', 'Score': 0.8494208494208494},
#  {'Metric': 'roc_auc', 'Score': np.float64(0.917906746031746)}]

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %% [markdown]
# ##### Cross - Validation

# %%
metrics = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc']

knn_cross_val = []

knn = KNeighborsClassifier(n_neighbors=5)

for metric in metrics:
    cv_scores = cross_val_score(
        knn,
        X_train_scaled,
        y_train,
        cv=5,
        scoring=metric
        )
    
    mean_score = cv_scores.mean()
    
    # Print (optional)
    print(f"\nCross-validated {metric} scores: {cv_scores}")
    print(f"KNN - Mean CV {metric}: {mean_score:.4f}")
    
    # Store in list
    knn_cross_val.append({
        'Metric': metric,
        'Fold 1': cv_scores[0],
        'Fold 2': cv_scores[1],
        'Fold 3': cv_scores[2],
        'Fold 4': cv_scores[3],
        'Fold 5': cv_scores[4],
        'Mean': mean_score
    })
    
# convert to df
knn_cv_df = pd.DataFrame(knn_cross_val)
display(knn_cv_df)
knn_cv_df.to_csv("metricx_insight/knn_cv_df.csv")
# Out:
# Cross-validated accuracy scores: [0.86387435 0.81151832 0.86842105 0.84210526 0.85789474]
# KNN - Mean CV accuracy: 0.8488
#
# Cross-validated precision scores: [0.8440367  0.82178218 0.86538462 0.89772727 0.83486239]
# KNN - Mean CV precision: 0.8528
#
# Cross-validated recall scores: [0.91089109 0.82178218 0.89108911 0.79       0.91      ]
# KNN - Mean CV recall: 0.8648
#
# Cross-validated f1 scores: [0.87619048 0.82178218 0.87804878 0.84042553 0.8708134 ]
# KNN - Mean CV f1: 0.8575
#
# Cross-validated roc_auc scores: [0.89939494 0.89251925 0.91689843 0.89638889 0.91522222]
# KNN - Mean CV roc_auc: 0.9041
#       Metric    Fold 1    Fold 2    Fold 3    Fold 4    Fold 5      Mean
# 0   accuracy  0.863874  0.811518  0.868421  0.842105  0.857895  0.848763
# 1  precision  0.844037  0.821782  0.865385  0.897727  0.834862  0.852759
# 2     recall  0.910891  0.821782  0.891089  0.790000  0.910000  0.864752
# 3         f1  0.876190  0.821782  0.878049  0.840426  0.870813  0.857452
# ...

# %%
# Set figure size
plt.figure(figsize=(8, 5))

# Bar chart of mean CV scores
plt.bar(knn_cv_df['Metric'],
        knn_cv_df['Mean'],
        color='#2D3142',
        edgecolor='#BFC0C0'
        )

# Add labels and title
plt.title('Logistic Regression - Mean Cross-Validation Scores', fontsize=14)
plt.xlabel('Metric', fontsize=12)
plt.ylabel('Mean CV Score', fontsize=12)

# Display mean values on bars
for i, v in enumerate(knn_cv_df['Mean']):
    plt.text(i, v+0.01, f'{v:.3f}', ha='center', color='white', weight='bold', fontsize=10)

plt.ylim(0, 1)
plt.show()

# %% [markdown]
# ##### Hypterparameter Tunnig

# %%
# Hyperparameter tuning
param_grid = {
    'n_neighbors': range(3, 21, 2),
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}

knn_ht_results = []

for metric in metrics:
    grid_knn = GridSearchCV(
        KNeighborsClassifier(),
        param_grid,
        scoring=metric,
        cv=5,
        n_jobs=-1
    )
    grid_knn.fit(X_train_scaled, y_train)
    
    mean_score = grid_knn.best_score_
    
    # Extract per-fold results
    fold_scores = [grid_knn.cv_results_[f'split{i}_test_score'].mean() for i in range(5)]
    
    print(f"\n===== Metric: {metric.upper()} =====")
    print("Best Parameters:", grid_knn.best_params_)
    print("Best CV Mean Score:", round(mean_score, 4))
    
    knn_ht_results.append({
        'Metric': metric,
        'Fold 1': fold_scores[0],
        'Fold 2': fold_scores[1],
        'Fold 3': fold_scores[2],
        'Fold 4': fold_scores[3],
        'Fold 5': fold_scores[4],
        'Mean': mean_score
    })
    
# convert todf
knn_hyper_tunning_df = pd.DataFrame(knn_ht_results)
display(knn_hyper_tunning_df)
knn_hyper_tunning_df.to_csv("metricx_insight/knn_hyper_tunning_df.csv")
# Out:
# ===== Metric: ACCURACY =====
# Best Parameters: {'metric': 'manhattan', 'n_neighbors': 13, 'weights': 'distance'}
# Best CV Mean Score: 0.9065
#
# ===== Metric: PRECISION =====
# Best Parameters: {'metric': 'euclidean', 'n_neighbors': 9, 'weights': 'distance'}
# Best CV Mean Score: 0.9079
#
# ===== Metric: RECALL =====
# Best Parameters: {'metric': 'manhattan', 'n_neighbors': 15, 'weights': 'distance'}
# Best CV Mean Score: 0.9205
#
# ===== Metric: F1 =====
# Best Parameters: {'metric': 'manhattan', 'n_neighbors': 13, 'weights': 'distance'}
# Best CV Mean Score: 0.9124
#
# ===== Metric: ROC_AUC =====
# Best Parameters: {'metric': 'manhattan', 'n_neighbors': 17, 'weights': 'distance'}
# Best CV Mean Score: 0.9576
#       Metric    Fold 1    Fold 2    Fold 3    Fold 4    Fold 5      Mean
# 0   accuracy  0.868674  0.868819  0.886550  0.862427  0.872807  0.906520
# 1  precision  0.854488  0.899567  0.883945  0.896588  0.862541  0.907920
# ...

# %%
# plot graph
plt.figure(figsize=(8, 5))
plt.bar(knn_hyper_tunning_df['Metric'],
        knn_hyper_tunning_df['Mean'],
        color='#2D3142',
        edgecolor='#BFC0C0'
        )

plt.title("KNN - Hyperparameter Tunnig", fontsize=14)
plt.xlabel('Metric', fontsize=12)
plt.ylabel('HT', fontsize=12)

for i,v in enumerate(knn_hyper_tunning_df['Mean']):
    plt.text(i, v+0.01, f'{v:.3f}', ha='center', color='white', weight='bold', fontsize=10)
    
plt.ylim(0, 1)
plt.show()

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# I used GridSearchCV for hyperparameter tuning. This method systematically explores all possible combinations of the specified hyperparameters within the defined grid.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Yes, hyperparameter tuning significantly improved the KNN model's performance across all metrics. The mean cross-validation scores increased noticeably after tuning, as shown by comparing the "Mean CV Score" bar charts.

# %% [markdown]
# ### ML Model - 3: K - Support Vector Machine(SVM)

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
svm = SVC(
    probability=True,
    random_state=42
    )

svm.fit(X_train_scaled, y_train)

# predic
y_pred_svm = svm.predict(X_test_scaled)
y_proba_svm = svm.predict_proba(X_test_scaled)[:, 1]

# %%
# function metric are already defined
svm_evaluation_results = []

for metric in metrics:
    func = metric_functions[metric]  # getting the actual function
        
    if metric != "roc_auc":
        score = func(y_test, y_pred_svm)
    else:
        score = func(y_test, y_proba_svm)
    
    svm_evaluation_results.append({
        'Metric': metric,
        'Score': score
    })
    
display(svm_evaluation_results)

# plot the graph
metric_names = [result['Metric'] for result in svm_evaluation_results]
metric_scores = [result['Score'] for result in svm_evaluation_results]

plt.figure(figsize=(10,5))
sns.barplot(
    x=metric_names,
    y=metric_scores,
    hue=metric_names,
    palette='viridis'
    )

# Display mean values on bars
for i, v in enumerate(metric_scores):
    plt.text(i, v+0.01, f'{v:.3f}', ha='center', color='white', weight='bold', fontsize=10)

plt.title("SVM Evaluation Metrics")
plt.ylim(0, 1)
plt.ylabel("Score")
plt.show()
# Out:
# [{'Metric': 'accuracy', 'Score': 0.8781512605042017},
#  {'Metric': 'precision', 'Score': 0.8646616541353384},
#  {'Metric': 'recall', 'Score': 0.9126984126984127},
#  {'Metric': 'f1', 'Score': 0.888030888030888},
#  {'Metric': 'roc_auc', 'Score': np.float64(0.9352324263038548)}]

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %% [markdown]
# ##### Cross - Validation

# %%
svm = SVC(probability=True, random_state=42)

svm_cross_val = []

for metric in metrics:
    cv_scores = cross_val_score(svm, X_train_scaled, y_train, cv=5, scoring=metric)
    mean_score = cv_scores.mean()
    
    # Print (optional)
    print(f"\nCross-validated {metric} scores: {cv_scores}")
    print(f"SVM - Mean CV {metric}: {mean_score:.4f}")
    
    # Store in list
    svm_cross_val.append({
        'Metric': metric,
        'Fold 1': cv_scores[0],
        'Fold 2': cv_scores[1],
        'Fold 3': cv_scores[2],
        'Fold 4': cv_scores[3],
        'Fold 5': cv_scores[4],
        'Mean': mean_score
    })
    
# convert to df
svm_cv_df = pd.DataFrame(svm_cross_val)
display(svm_cv_df)
svm_cv_df.to_csv("metricx_insight/svm_cv_df.csv")
# Out:
# Cross-validated accuracy scores: [0.83246073 0.85340314 0.86315789 0.84736842 0.89473684]
# SVM - Mean CV accuracy: 0.8582
#
# Cross-validated precision scores: [0.81651376 0.86138614 0.85046729 0.86597938 0.87037037]
# SVM - Mean CV precision: 0.8529
#
# Cross-validated recall scores: [0.88118812 0.86138614 0.9009901  0.84       0.94      ]
# SVM - Mean CV recall: 0.8847
#
# Cross-validated f1 scores: [0.84761905 0.86138614 0.875      0.85279188 0.90384615]
# SVM - Mean CV f1: 0.8681
#
# Cross-validated roc_auc scores: [0.90583058 0.90715072 0.9276894  0.92622222 0.93366667]
# SVM - Mean CV roc_auc: 0.9201
#       Metric    Fold 1    Fold 2    Fold 3    Fold 4    Fold 5      Mean
# 0   accuracy  0.832461  0.853403  0.863158  0.847368  0.894737  0.858225
# 1  precision  0.816514  0.861386  0.850467  0.865979  0.870370  0.852943
# 2     recall  0.881188  0.861386  0.900990  0.840000  0.940000  0.884713
# 3         f1  0.847619  0.861386  0.875000  0.852792  0.903846  0.868129
# ...

# %%
plt.figure(figsize=(8, 5))
plt.bar(
    svm_cv_df['Metric'],
    svm_cv_df['Mean'],
    color='#2D3142',
    edgecolor='#BFC0C0'
)
plt.title('SVM- Mean Cross-Validation Scores', fontsize=14)
plt.xlabel('Metric', fontsize=12)
plt.ylabel('Mean CV Score', fontsize=12)

for i, v in enumerate(svm_cv_df['Mean']):
    plt.text(i, v+0.01, f'{v:.3f}', ha='center', color='white', weight='bold', fontsize=10)
    
plt.ylim(0, 1)
plt.show()

# %% [markdown]
# ##### Hyperperameter Tunning

# %%
# Hyperparameter tuning
param_grid = {
    'C': [0.1, 1, 10, 100],
    'kernel': ['linear', 'rbf', 'poly'],
    'gamma': ['scale', 'auto']
}

svm_ht_results = []

for metric in metrics:
    grid_svm = GridSearchCV(
        SVC(probability=True, random_state=42),
        param_grid,
        scoring=metric,
        cv=5,
        n_jobs=-1
    )
    grid_svm.fit(X_train_scaled, y_train)
    
    mean_score = grid_svm.best_score_
    
    # Extract per-fold results
    fold_scores = [grid_svm.cv_results_[f'split{i}_test_score'].mean() for i in range(5)]
    
    print(f"\n===== Metric: {metric.upper()} =====")
    print("Best Parameters:", grid_svm.best_params_)
    # print(grid_log_reg)
    print("Best CV Mean Score:", round(mean_score, 4))
    
    svm_ht_results.append({
        'Metric': metric,
        'Fold 1': fold_scores[0],
        'Fold 2': fold_scores[1],
        'Fold 3': fold_scores[2],
        'Fold 4': fold_scores[3],
        'Fold 5': fold_scores[4],
        'Mean': mean_score
    })
    
# convert to df
svm_hyper_tunning_df = pd.DataFrame(svm_ht_results)
display(svm_hyper_tunning_df)
svm_hyper_tunning_df.to_csv("metricx_insight/svm_hyper_tunning_df.csv")
# Out:
# ===== Metric: ACCURACY =====
# Best Parameters: {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}
# Best CV Mean Score: 0.8687
#
# ===== Metric: PRECISION =====
# Best Parameters: {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}
# Best CV Mean Score: 0.8826
#
# ===== Metric: RECALL =====
# Best Parameters: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Best CV Mean Score: 0.8847
#
# ===== Metric: F1 =====
# Best Parameters: {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}
# Best CV Mean Score: 0.8745
#
# ===== Metric: ROC_AUC =====
# Best Parameters: {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
# Best CV Mean Score: 0.9269
#       Metric    Fold 1    Fold 2    Fold 3    Fold 4    Fold 5      Mean
# 0   accuracy  0.821553  0.833988  0.847588  0.846272  0.866447  0.868741
# 1  precision  0.824169  0.855436  0.844954  0.881639  0.862042  0.882635
# 2     recall  0.842822  0.825908  0.873762  0.818333  0.889583  0.884713
# 3         f1  0.833228  0.840112  0.859044  0.848505  0.875206  0.874457
# ...

# %%
# create the graph
plt.figure(figsize=(8,5))

plt.bar(
    svm_hyper_tunning_df['Metric'],
    svm_hyper_tunning_df['Mean'],
    color='#2D3142',
    edgecolor='#BFC0C0'
    )

plt.title('SVM - Mean Cross-Validation Scores', fontsize=14)
plt.xlabel('Metric', fontsize=12)
plt.ylabel('Mean CV Score', fontsize=12)

for i, v in enumerate(svm_hyper_tunning_df['Mean']):
    plt.text(i, v+0.01, f'{v:.3f}', ha='center', color='white', weight='bold', fontsize=10)

plt.ylim(0, 1)
plt.show()

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# I used GridSearchCV for hyperparameter tuning. It systematically searches through a defined grid of hyperparameters to find the optimal values for the SVM model.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Yes, hyperparameter tuning led to some improvements in the SVM model's performance, particularly in accuracy, precision, and F1 score. You can see the increase in the mean cross-validation scores in the bar charts before and after tuning.

# %% [markdown]
# ### ML Model - 4: Decission Tree

# %%
# ML MODEL 4: Descission Tree

dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)

# prdict
y_pred_dt = dt.predict(X_test)
y_proba_dt = dt.predict_proba(X_test)[:, 1]

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
dt_evaluation_results = []

for metric in metrics:
    func = metric_functions[metric]  # getting the actual function
        
    if metric != "roc_auc":
        score = func(y_test, y_pred_dt)
    else:
        score = func(y_test, y_proba_dt)
    
    dt_evaluation_results.append({
        'Metric': metric,
        'Score': score
    })
        
display(dt_evaluation_results)

# plot the graph
metric_names = [result['Metric'] for result in dt_evaluation_results]
metric_scores = [result['Score'] for result in dt_evaluation_results]

plt.figure(figsize=(10,5))
sns.barplot(
    x=metric_names,
    y=metric_scores,
    hue=metric_names,
    palette='viridis'
    )

# Display mean values on bars
for i, v in enumerate(metric_scores):
    plt.text(i, v+0.01, f'{v:.3f}', ha='center', color='white', weight='bold', fontsize=10)

plt.title("Decission Tree Evaluation Metrics")
plt.ylim(0, 1)
plt.ylabel("Score")
plt.show()
# Out:
# [{'Metric': 'accuracy', 'Score': 0.8781512605042017},
#  {'Metric': 'precision', 'Score': 0.9145299145299145},
#  {'Metric': 'recall', 'Score': 0.8492063492063492},
#  {'Metric': 'f1', 'Score': 0.8806584362139918},
#  {'Metric': 'roc_auc', 'Score': np.float64(0.8799603174603176)}]

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %% [markdown]
# ##### Cross - validation

# %%
dt_cross_val = []

for metric in metrics:
    cv_scores = cross_val_score(dt, X_train, y_train, cv=5, scoring=metric)
    mean_score = cv_scores.mean()
    
    # Print (optional)
    print(f"\nCross-validated {metric} scores: {cv_scores}")
    print(f"Decision Tree - Mean CV {metric}: {mean_score:.4f}")
    
    # Store in list
    dt_cross_val.append({
        'Metric': metric,
        'Fold 1': cv_scores[0],
        'Fold 2': cv_scores[1],
        'Fold 3': cv_scores[2],
        'Fold 4': cv_scores[3],
        'Fold 5': cv_scores[4],
        'Mean': mean_score
    })
    
# convert to df
dt_cv_df = pd.DataFrame(dt_cross_val)
display(dt_cv_df)
dt_cv_df.to_csv("metricx_insight/dt_cv_df.csv")
# Out:
# Cross-validated accuracy scores: [0.85863874 0.84293194 0.89473684 0.87368421 0.87368421]
# Decision Tree - Mean CV accuracy: 0.8687
#
# Cross-validated precision scores: [0.87       0.87368421 0.89320388 0.88       0.89583333]
# Decision Tree - Mean CV precision: 0.8825
#
# Cross-validated recall scores: [0.86138614 0.82178218 0.91089109 0.88       0.86      ]
# Decision Tree - Mean CV recall: 0.8668
#
# Cross-validated f1 scores: [0.86567164 0.84693878 0.90196078 0.88       0.87755102]
# Decision Tree - Mean CV f1: 0.8744
#
# Cross-validated roc_auc scores: [0.85847085 0.84422442 0.89364779 0.87333333 0.87444444]
# Decision Tree - Mean CV roc_auc: 0.8688
#       Metric    Fold 1    Fold 2    Fold 3    Fold 4    Fold 5      Mean
# 0   accuracy  0.858639  0.842932  0.894737  0.873684  0.873684  0.868735
# 1  precision  0.870000  0.873684  0.893204  0.880000  0.895833  0.882544
# 2     recall  0.861386  0.821782  0.910891  0.880000  0.860000  0.866812
# ...

# %%
# Set figure size
plt.figure(figsize=(8, 5))

# Bar chart of mean CV scores
plt.bar(dt_cv_df['Metric'],
        dt_cv_df['Mean'],
        color='#2D3142',
        edgecolor='#BFC0C0'
        )

# Add labels and title
plt.title('Logistic Regression - Mean Cross-Validation Scores', fontsize=14)
plt.xlabel('Metric', fontsize=12)
plt.ylabel('Mean CV Score', fontsize=12)

# Display mean values on bars
for i, v in enumerate(dt_cv_df['Mean']):
    plt.text(i, v+0.01, f'{v:.3f}', ha='center', color='white', weight='bold', fontsize=10)

plt.ylim(0, 1)
plt.show()

# %% [markdown]
# ##### Hyperparameter Tunning

# %%
# Hyperparameter tuning
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [3, 5, 7, 9, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

dt_ht_results = []

for metric in metrics:
    grid_dt = GridSearchCV(
        DecisionTreeClassifier(random_state=42),
        param_grid,
        cv=5,
        scoring=metric,
        n_jobs=-1)
    
    grid_dt.fit(X_train, y_train)
    
    mean_score = grid_dt.best_score_
    
    # Extract per-fold results
    fold_scores = [grid_dt.cv_results_[f'split{i}_test_score'].mean() for i in range(5)]
    
    print(f"\n===== Metric: {metric.upper()} =====")
    print("Best Parameters:", grid_dt.best_params_)
    # print(grid_log_reg)
    print("Best CV Mean Score:", round(mean_score, 4))
    
    dt_ht_results.append({
        'Metric': metric,
        'Fold 1': fold_scores[0],
        'Fold 2': fold_scores[1],
        'Fold 3': fold_scores[2],
        'Fold 4': fold_scores[3],
        'Fold 5': fold_scores[4],
        'Mean': mean_score
    })
    
# convert to df
dt_hyper_tunning_df = pd.DataFrame(dt_ht_results)
display(dt_hyper_tunning_df)
dt_hyper_tunning_df.to_csv("metricx_insight/dt_hyper_tunning_df.csv")
# Out:
# ===== Metric: ACCURACY =====
# Best Parameters: {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Best CV Mean Score: 0.8792
#
# ===== Metric: PRECISION =====
# Best Parameters: {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Best CV Mean Score: 0.8943
#
# ===== Metric: RECALL =====
# Best Parameters: {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Best CV Mean Score: 0.8747
#
# ===== Metric: F1 =====
# Best Parameters: {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Best CV Mean Score: 0.8842
#
# ===== Metric: ROC_AUC =====
# Best Parameters: {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Best CV Mean Score: 0.9068
#       Metric    Fold 1    Fold 2    Fold 3    Fold 4    Fold 5      Mean
# 0   accuracy  0.825247  0.816987  0.851579  0.837895  0.839942  0.879223
# ...

# %%
# plot this
# Set figure size
plt.figure(figsize=(8, 5))

# Bar chart of mean CV scores
plt.bar(dt_hyper_tunning_df['Metric'],
        dt_hyper_tunning_df['Mean'],
        color='#2D3142',
        edgecolor='#BFC0C0'
        )

# Add labels and title
plt.title('Decission Tree - Hyperparameter Tunning', fontsize=14)
plt.xlabel('Metric', fontsize=12)
plt.ylabel('HT', fontsize=12)

# Display mean values on bars
for i, v in enumerate(dt_hyper_tunning_df['Mean']):
    plt.text(i, v+0.01, f'{v:.3f}', ha='center', color='white', weight='bold', fontsize=10)

plt.ylim(0, 1)
plt.show()

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# I used GridSearchCV for hyperparameter tuning. This method explores all possible combinations of the hyperparameters in the specified grid to find the best configuration for the Decision Tree model.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Yes, hyperparameter tuning resulted in some improvements for the Decision Tree model, especially in accuracy, precision, and F1 score. The mean cross-validation scores for these metrics increased after tuning.

# %% [markdown]
# ### ML Model - 5: Random Forest Classifier

# %%
# ML MODEL 5: RandomForest
rf= RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

# Predict
y_pred_rf = rf.predict(X_test)
y_proba_rf = rf.predict_proba(X_test)[:, 1]

# %%
# Evalution metric of rf
rf_evaluation_results = []

for metric in metrics:
    func = metric_functions[metric]  # getting the actual function
        
    if metric != "roc_auc":
        score = func(y_test, y_pred_rf)
    else:
        score = func(y_test, y_proba_rf)
    
    rf_evaluation_results.append({
        'Metric': metric,
        'Score': score
    })
display(rf_evaluation_results)
# Out:
# [{'Metric': 'accuracy', 'Score': 0.9243697478991597},
#  {'Metric': 'precision', 'Score': 0.9285714285714286},
#  {'Metric': 'recall', 'Score': 0.9285714285714286},
#  {'Metric': 'f1', 'Score': 0.9285714285714286},
#  {'Metric': 'roc_auc', 'Score': np.float64(0.9713364512471655)}]

# %%
# plot the graph
metric_names = [result['Metric'] for result in rf_evaluation_results]
metric_scores = [result['Score'] for result in rf_evaluation_results]

plt.figure(figsize=(10,5))
sns.barplot(
    x=metric_names,
    y=metric_scores,
    hue=metric_names,
    palette='viridis'
    )

# Display mean values on bars
for i, v in enumerate(metric_scores):
    plt.text(i, v+0.01, f'{v:.3f}', ha='center', color='white', weight='bold', fontsize=10)

plt.title("Random Forest Evaluation Metrics")
plt.ylim(0, 1.1)
plt.ylabel("Score")
plt.show()

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %% [markdown]
# ##### Cross - Validation

# %%
# Create an empty list to store results
rf_cross_val = []

# Cross-validation for each metric
rf = RandomForestClassifier(n_estimators=100, random_state=42)

for metric in metrics:
    cv_scores = cross_val_score(
        rf,
        X_train_scaled,
        y_train,
        cv=5,
        scoring=metric
        )
    
    mean_score = cv_scores.mean()
    
    # Print (optional)
    print(f"\nCross-validated {metric} scores: {cv_scores}")
    print(f"Logistic Regression - Mean CV {metric}: {mean_score:.4f}")
    
    # Store in list
    rf_cross_val.append({
        'Metric': metric,
        'Fold 1': cv_scores[0],
        'Fold 2': cv_scores[1],
        'Fold 3': cv_scores[2],
        'Fold 4': cv_scores[3],
        'Fold 5': cv_scores[4],
        'Mean': mean_score
    })

# Convert to DataFrame
rf_cv_df = pd.DataFrame(rf_cross_val)
display(rf_cv_df)
rf_cv_df.to_csv("metricx_insight/rf_cv_df.csv")

# plot the graph
# Set figure size
plt.figure(figsize=(8, 5))

# Bar chart of mean CV scores
plt.bar(rf_cv_df['Metric'],
        rf_cv_df['Mean'],
        color='#2D3142',
        edgecolor='#BFC0C0'
        )

# Add labels and title
plt.title('Random Forest - Mean Cross-Validation Scores', fontsize=14)
plt.xlabel('Metric', fontsize=12)
plt.ylabel('Mean CV Score', fontsize=12)

# Display mean values on bars
for i, v in enumerate(rf_cv_df['Mean']):
    plt.text(i, v+0.01, f'{v:.3f}', ha='center', color='white', weight='bold', fontsize=10)

plt.ylim(0, 1)
plt.show()
# Out:
# Cross-validated accuracy scores: [0.87434555 0.91623037 0.93157895 0.92105263 0.90526316]
# Logistic Regression - Mean CV accuracy: 0.9097
#
# Cross-validated precision scores: [0.85321101 0.93814433 0.92307692 0.93814433 0.90196078]
# Logistic Regression - Mean CV precision: 0.9109
#
# Cross-validated recall scores: [0.92079208 0.9009901  0.95049505 0.91       0.92      ]
# Logistic Regression - Mean CV recall: 0.9205
#
# Cross-validated f1 scores: [0.88571429 0.91919192 0.93658537 0.92385787 0.91089109]
# Logistic Regression - Mean CV f1: 0.9152
#
# Cross-validated roc_auc scores: [0.91716172 0.93943894 0.94971632 0.96922222 0.94594444]
# Logistic Regression - Mean CV roc_auc: 0.9443
#       Metric    Fold 1    Fold 2    Fold 3    Fold 4    Fold 5      Mean
# 0   accuracy  0.874346  0.916230  0.931579  0.921053  0.905263  0.909694
# 1  precision  0.853211  0.938144  0.923077  0.938144  0.901961  0.910907
# 2     recall  0.920792  0.900990  0.950495  0.910000  0.920000  0.920455
# ...

# %% [markdown]
# ##### HyperParameter Tunning

# %%
# Hyperparameter tuning (use RandomizedSearchCV for efficiency)
param_dist = {
    'n_estimators': [100, 200, 300],
    'max_depth': [5, 10, 15, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

rf_ht_results = []

for metric in metrics:
    rand_rf = RandomizedSearchCV(
        RandomForestClassifier(random_state=42),
        param_distributions=param_dist,
        n_iter=10, 
        cv=5,
        scoring=metric,
        n_jobs=-1,
        random_state=42
    )
    rand_rf.fit(X_train, y_train)
    
    mean_score = rand_rf.best_score_
    
    # Extract per-fold results
    fold_scores = [rand_rf.cv_results_[f'split{i}_test_score'].mean() for i in range(5)]
    
    print(f"\n===== Metric: {metric.upper()} =====")
    print("Best Parameters:", rand_rf.best_params_)
    print("Best CV Mean Score:", round(mean_score, 4))
    
    rf_ht_results.append({
        'Metric': metric,
        'Fold 1': fold_scores[0],
        'Fold 2': fold_scores[1],
        'Fold 3': fold_scores[2],
        'Fold 4': fold_scores[3],
        'Fold 5': fold_scores[4],
        'Mean': mean_score
    })
    
# convert to df
rf_hyper_tunning_df = pd.DataFrame(rf_ht_results)
display(rf_hyper_tunning_df)
rf_hyper_tunning_df.to_csv("metricx_insight/rf_hyper_tunning_df.csv")

# let's plot it's graph
plt.figure(figsize=(8, 5))
plt.bar(
    rf_hyper_tunning_df['Metric'],
    rf_hyper_tunning_df['Mean'],
    color='#2D3142',
    edgecolor='#BFC0C0'
    )

plt.title('Random Forest - Hyperparameter Tunning', fontsize=14)
plt.xlabel('Metric', fontsize=12)
plt.ylabel('HT', fontsize=12)

for i, v in enumerate(rf_hyper_tunning_df['Mean']):
    plt.text(i, v+0.01, f'{v:.3f}', ha='center', color='white', weight='bold', fontsize=10)
    
plt.ylim(0, 1)
plt.show()
# Out:
# ===== Metric: ACCURACY =====
# Best Parameters: {'n_estimators': 200, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': False}
# Best CV Mean Score: 0.9076
#
# ===== Metric: PRECISION =====
# Best Parameters: {'n_estimators': 200, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_depth': None, 'bootstrap': False}
# Best CV Mean Score: 0.9033
#
# ===== Metric: RECALL =====
# Best Parameters: {'n_estimators': 200, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': False}
# Best CV Mean Score: 0.9264
#
# ===== Metric: F1 =====
# Best Parameters: {'n_estimators': 200, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': False}
# Best CV Mean Score: 0.9139
#
# ===== Metric: ROC_AUC =====
# Best Parameters: {'n_estimators': 100, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_depth': None, 'bootstrap': False}
# Best CV Mean Score: 0.9469
# ...

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# I used RandomizedSearchCV for hyperparameter tuning. This technique samples a fixed number of hyperparameter combinations from a specified distribution. I chose this for efficiency, especially with a larger parameter space.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Yes, hyperparameter tuning with RandomizedSearchCV led to improvements for the Random Forest model across most metrics. The mean cross-validation scores, particularly for accuracy, precision, recall, and F1 score, show an increase after tuning.

# %% [markdown]
# ### ML Model - 6: XGBoost

# %%
# ML model 6: XGBoost
# Initialize the model
xgb = XGBClassifier(
    n_estimators=200,
    learning_rate=0.05,
    max_depth=4,
    random_state=42,
    eval_metric='logloss'  
)

xgb.fit(X_train, y_train)

# Predict
y_pred_xgb = xgb.predict(X_test)
y_proba_xgb = xgb.predict_proba(X_test)[:, 1]

# %%
# Evaluation metric 
xgb_evaluation_results = []

for metric in metrics:
    func = metric_functions[metric]  # getting the actual function
        
    if metric != "roc_auc":
        score = func(y_test, y_pred_xgb)
    else:
        score = func(y_test, y_proba_xgb)
    
    xgb_evaluation_results.append({
        'Metric': metric,
        'Score': score
    })

display(xgb_evaluation_results)

# plot the graph
metric_names = [result['Metric'] for result in xgb_evaluation_results]
metric_scores = [result['Score'] for result in xgb_evaluation_results]

plt.figure(figsize=(8, 5))

sns.barplot(
    x=metric_names,
    y=metric_scores,
    hue=metric_names,
    palette='viridis'
    )
# Display mean values on bars
for i, v in enumerate(metric_scores):
    plt.text(i, v+0.01, f'{v:.3f}', ha='center', color='white', weight='bold', fontsize=10)

plt.title("XGBoost Evaluation Metrics")
plt.ylim(0, 1.1)
plt.ylabel("Score")
plt.xlabel("Metric")
plt.show()
# Out:
# [{'Metric': 'accuracy', 'Score': 0.9117647058823529},
#  {'Metric': 'precision', 'Score': 0.926829268292683},
#  {'Metric': 'recall', 'Score': 0.9047619047619048},
#  {'Metric': 'f1', 'Score': 0.9156626506024096},
#  {'Metric': 'roc_auc', 'Score': np.float64(0.9599631519274378)}]

# %% [markdown]
# #### 2. Cross-Validation & Hyperparameter tuning

# %% [markdown]
# Cross -Validatiion

# %%
xgb_cross_val = []

xgb = XGBClassifier(
    n_estimators=200,
    learning_rate=0.05,
    max_depth=4,
    random_state=42,
    eval_metric='logloss'  
)

for metric in metrics:
    cv_scores = cross_val_score(xgb, X_train, y_train, cv=5, scoring=metric)
    mean_score = cv_scores.mean()
    
    # Print (optional)
    print(f"\nCross-validated {metric} scores: {cv_scores}")
    print(f"XGBoost - Mean CV {metric}: {mean_score:.4f}")
    
    # Store in list
    xgb_cross_val.append({
        'Metric': metric,
        'Fold 1': cv_scores[0],
        'Fold 2': cv_scores[1],
        'Fold 3': cv_scores[2],
        'Fold 4': cv_scores[3],
        'Fold 5': cv_scores[4],
        'Mean': mean_score
    })
    
# convert to df
xgb_cv_df = pd.DataFrame(xgb_cross_val)
display(xgb_cv_df)
xgb_cv_df.to_csv("metricx_insight/xgb_cv_df.csv")

# graph it
plt.figure(figsize=(8, 5))
plt.bar(
    xgb_cv_df['Metric'],
    xgb_cv_df['Mean'],
    color='#2D3142',
    edgecolor='#BFC0C0'
    )
plt.title('XGBoost - Mean Cross-Validation Scores', fontsize=14)
plt.xlabel('Metric', fontsize=12)
plt.ylabel('Mean CV Score', fontsize=12)
for i, v in enumerate(xgb_cv_df['Mean']):
    plt.text(i, v+0.01, f'{v:.3f}', ha='center', color='white', weight='bold', fontsize=10)

plt.ylim(0, 1)
plt.show()
# Out:
# Cross-validated accuracy scores: [0.87434555 0.89005236 0.89473684 0.88947368 0.88947368]
# XGBoost - Mean CV accuracy: 0.8876
#
# Cross-validated precision scores: [0.85321101 0.91666667 0.87155963 0.92473118 0.87619048]
# XGBoost - Mean CV precision: 0.8885
#
# Cross-validated recall scores: [0.92079208 0.87128713 0.94059406 0.86       0.92      ]
# XGBoost - Mean CV recall: 0.9025
#
# Cross-validated f1 scores: [0.88571429 0.89340102 0.9047619  0.89119171 0.89756098]
# XGBoost - Mean CV f1: 0.8945
#
# Cross-validated roc_auc scores: [0.92827283 0.93311331 0.94815886 0.95022222 0.93888889]
# XGBoost - Mean CV roc_auc: 0.9397
#       Metric    Fold 1    Fold 2    Fold 3    Fold 4    Fold 5      Mean
# 0   accuracy  0.874346  0.890052  0.894737  0.889474  0.889474  0.887616
# 1  precision  0.853211  0.916667  0.871560  0.924731  0.876190  0.888472
# 2     recall  0.920792  0.871287  0.940594  0.860000  0.920000  0.902535
# ...

# %% [markdown]
# Hyperparameter tuning

# %%
# Hyperparameter tuning (randomized search for speed)
param_dist = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [3, 4, 5, 6],
    'subsample': [0.8, 0.9, 1.0],
    'colsample_bytree': [0.8, 0.9, 1.0]
}

xgb_ht_results = []

for metric in metrics:
    rand_xgb = RandomizedSearchCV(
        XGBClassifier(random_state=42, eval_metric='logloss'),
        param_distributions=param_dist,
        n_iter=10,
        cv=5,
        scoring=metric,
        n_jobs=-1,
        random_state=42
    )
    rand_xgb.fit(X_train, y_train)
    
    mean_score = rand_xgb.best_score_
    
    # Extract per-fold results
    fold_scores = [rand_xgb.cv_results_[f'split{i}_test_score'].mean() for i in range(5)]
    
    print(f"\n===== Metric: {metric.upper()} =====")
    print("Best Parameters:", rand_xgb.best_params_)
    print("Best CV Mean Score:", round(mean_score, 4))
    
    xgb_ht_results.append({
        'Metric': metric,
        'Fold 1': fold_scores[0],
        'Fold 2': fold_scores[1],
        'Fold 3': fold_scores[2],
        'Fold 4': fold_scores[3],
        'Fold 5': fold_scores[4],
        'Mean': mean_score
    })

# convert to df
xgb_hyper_tunning_df = pd.DataFrame(xgb_ht_results)
display(xgb_hyper_tunning_df)
xgb_hyper_tunning_df.to_csv("metricx_insight/xgb_hyper_tunning_df.csv")

# graph it
plt.figure(figsize=(8, 5))
plt.bar(
    xgb_hyper_tunning_df['Metric'],
    xgb_hyper_tunning_df['Mean'],
    color='#2D3142',
    edgecolor='#BFC0C0'
    )
plt.title('XGBoost - Hyperparameter Tunning', fontsize=14)
plt.xlabel('Metric', fontsize=12)
plt.ylabel('HT', fontsize=12)
for i, v in enumerate(xgb_hyper_tunning_df['Mean']):
    plt.text(i, v+0.01, f'{v:.3f}', ha='center', color='white', weight='bold', fontsize=10)
plt.ylim(0, 1)
plt.show()
# Out:
# ===== Metric: ACCURACY =====
# Best Parameters: {'subsample': 0.9, 'n_estimators': 300, 'max_depth': 4, 'learning_rate': 0.1, 'colsample_bytree': 0.9}
# Best CV Mean Score: 0.8992
#
# ===== Metric: PRECISION =====
# Best Parameters: {'subsample': 0.9, 'n_estimators': 300, 'max_depth': 4, 'learning_rate': 0.1, 'colsample_bytree': 0.9}
# Best CV Mean Score: 0.897
#
# ===== Metric: RECALL =====
# Best Parameters: {'subsample': 0.9, 'n_estimators': 300, 'max_depth': 4, 'learning_rate': 0.1, 'colsample_bytree': 0.9}
# Best CV Mean Score: 0.9145
#
# ===== Metric: F1 =====
# Best Parameters: {'subsample': 0.9, 'n_estimators': 300, 'max_depth': 4, 'learning_rate': 0.1, 'colsample_bytree': 0.9}
# Best CV Mean Score: 0.9055
#
# ===== Metric: ROC_AUC =====
# Best Parameters: {'subsample': 1.0, 'n_estimators': 200, 'max_depth': 4, 'learning_rate': 0.05, 'colsample_bytree': 1.0}
# Best CV Mean Score: 0.9397
#       Metric    Fold 1    Fold 2    Fold 3    Fold 4    Fold 5      Mean
# ...

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# I used RandomizedSearchCV for hyperparameter tuning. This approach samples a random subset of hyperparameter combinations, which is more computationally efficient than an exhaustive grid search, especially for models like XGBoost with many hyperparameters.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Yes, hyperparameter tuning using RandomizedSearchCV resulted in improvements for the XGBoost model in several metrics, including accuracy, precision, recall, and F1 score. The mean cross-validation scores reflect these positive changes.

# %% [markdown]
# ## ML COCLUSION

# %%
# f models that use scaled data
scaled_models = ["Logistic Regression", "K-Nearest Neighbors", "Support Vector Machine"]

# Collect models
models = {
    "Logistic Regression": grid_log_reg.best_estimator_,
    "K-Nearest Neighbors": grid_knn.best_estimator_,
    "Support Vector Machine": grid_svm.best_estimator_,
    "Decision Tree": grid_dt.best_estimator_,
    "Random Forest": rand_rf.best_estimator_,
    "XGBoost": rand_xgb.best_estimator_
}

# Evaluate all models
Overall_results = []

for name, model in models.items():
    # Use scaled or unscaled data
    X_test_used = X_test_scaled if name in scaled_models else X_test

    # Predictions
    y_pred = model.predict(X_test_used)

    # Probabilities (for ROC-AUC)
    if hasattr(model, "predict_proba"):
        y_proba = model.predict_proba(X_test_used)[:, 1]
    else:
        y_proba = None

    # Metrics
    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_proba)

    Overall_results.append({
        'Model': name,
        'Accuracy': acc,
        'Precision': prec,
        'Recall': rec,
        'F1 Score': f1,
        'ROC-AUC': roc_auc
    })

# Create DataFrame
df_results = pd.DataFrame(Overall_results).sort_values(by='Accuracy', ascending=False)
display(df_results)
# Out:
#                     Model  Accuracy  Precision    Recall  F1 Score   ROC-AUC
# 1     K-Nearest Neighbors  0.949580   0.959677  0.944444  0.952000  0.974915
# 4           Random Forest  0.915966   0.927419  0.912698  0.920000  0.974702
# 5                 XGBoost  0.911765   0.926829  0.904762  0.915663  0.959963
# 2  Support Vector Machine  0.894958   0.910569  0.888889  0.899598  0.946925
# 3           Decision Tree  0.865546   0.879032  0.865079  0.872000  0.927686
# 0     Logistic Regression  0.840336   0.843750  0.857143  0.850394  0.907029

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# So, the model we landed on as the best is K-Nearest Neighbors (KNN). How does it work? Imagine you have a new patient. KNN looks at the 'k' patients in our existing data who are most similar to this new patient (based on all their health numbers). Then, it simply predicts that the new patient has heart disease if most of those 'k' similar patients had it, and predicts they don't if most of those neighbors didn't. It's like saying, "Show me your friends, and I'll tell you who you are!"<br>
# Now, for which features were most important, KNN doesn't exactly tell us directly like some other models do. But, we did some analysis earlier (remember those charts around number 10 and 11?) with models like Random Forest and XGBoost that do tell us feature importance. Those analyses consistently showed that things like ST slope, chest pain type, maximum heart rate, oldpeak, and cholesterol were really strong predictors of heart disease. So, even though KNN works differently, we can feel pretty confident that these same features are likely the ones it's relying on heavily to make its predictions too. If we needed a super deep dive into why KNN made a specific prediction for a single patient, we could use some special tools called SHAP or LIME, but based on our overall analysis, those features I mentioned are the big players.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# Looking at how all the models performed, the K-Nearest Neighbors (KNN) model really stood out! After a bit of tuning, it gave us the best results on the test data. It had the highest accuracy, which means it was right more often, and also great scores for the F1 score and ROC-AUC, which are good signs it's balancing catching cases and not raising too many false alarms. The other models like Random Forest and XGBoost were good too, but KNN just edged them out on these important measures. So, KNN seems like our best bet for predicting heart disease with this dataset.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# When we think about how this project can actually help people, especially in healthcare, we need to look at a few key numbers:
#
# *   **Recall:** This is super important! It tells us how good our model is at catching *all* the actual heart disease cases. We really don't want to miss anyone who might be at risk, right?
# *   **Precision:** This one is about not raising false alarms. While catching everyone is the priority, we also don't want to tell someone they might have heart disease when they don't, as that can cause a lot of worry and lead to unnecessary tests.
# *   **ROC-AUC:** Think of this as an overall score of how well our model can tell the difference between someone with heart disease and someone without. A higher number here means it's doing a pretty good job at separating the two groups.
# *   **Accuracy:** This just tells us how often our model is right overall. It's a good general measure, but for something serious like heart disease, we need to look deeper at recall and precision too.

# %% [markdown]
# ## ***8.*** ***Future Work***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File
import joblib

# The best performing model is KNN based on the overall results
best_model = models["K-Nearest Neighbors"]

# Save the model to a file
filename = 'best_heart_disease_model.joblib'
joblib.dump(best_model, filename)

print(f"Best model saved to {filename}")
# Out:
# Best model saved to best_heart_disease_model.joblib

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.
# Load the saved model
filename = 'best_heart_disease_model.joblib'
loaded_model = joblib.load(filename)

print(f"Model loaded from {filename}")
# Out:
# Model loaded from best_heart_disease_model.joblib

# %% [markdown]
# ### Testing on whole dataset

# %%
# Predict on the entire test set
y_pred_loaded = loaded_model.predict(X_test_scaled)
y_proba_loaded = loaded_model.predict_proba(X_test_scaled)[:, 1]

print("Accuracy:", accuracy_score(y_test, y_pred_loaded))
print("Precision:", precision_score(y_test, y_pred_loaded))
print("Recall:", recall_score(y_test, y_pred_loaded))
print("F1 Score:", f1_score(y_test, y_pred_loaded))
print("ROC-AUC:", roc_auc_score(y_test, y_proba_loaded))
# Out:
# Accuracy: 0.9495798319327731
# Precision: 0.9596774193548387
# Recall: 0.9444444444444444
# F1 Score: 0.952
# ROC-AUC: 0.9749149659863945

# %% [markdown]
# ### Testing on few random unseen samples

# %%
sample_indices = np.random.choice(len(X_test_scaled), 5, replace=False)

for idx in sample_indices:
    sample = X_test_scaled[idx].reshape(1, -1)
    pred = loaded_model.predict(sample)[0]
    proba = loaded_model.predict_proba(sample)[0, 1]
    actual = y_test.iloc[idx]

    print(f"Sample {idx}: Prediction={pred}, Probability={proba:.3f}, Actual={actual}")
# Out:
# Sample 31: Prediction=1, Probability=1.000, Actual=0
# Sample 202: Prediction=1, Probability=0.523, Actual=1
# Sample 143: Prediction=0, Probability=0.187, Actual=1
# Sample 39: Prediction=0, Probability=0.000, Actual=0
# Sample 109: Prediction=1, Probability=0.944, Actual=1

# %% [markdown]
# #### Confusion metric

# %%
cm = confusion_matrix(y_test, y_pred_loaded)
ConfusionMatrixDisplay(cm).plot(cmap='Blues')
plt.title("Confusion Matrix for Loaded Model")
plt.show()
# Out:
# Exception ignored in: <function ResourceTracker.__del__ at 0x10311dbc0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x1067f1bc0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x10745dbc0>
# ...

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# <h3 id="summary" tabindex="0" aria-label="Heart Disease Prediction Conclusion">
#   <span class="line">🏁 <b>Conclusion:</b> This project focused on predicting heart disease using various health indicators and patient metrics.</span>
#   <span class="line">📊 Extensive <b>Exploratory Data Analysis (EDA)</b> was performed to understand feature distributions, identify key patterns, and handle missing or duplicate values.</span>
#   <span class="line">🧠 Multiple <b>machine learning models</b> were implemented and evaluated — including Logistic Regression, KNN, SVM, Decision Tree, Random Forest, and XGBoost.</span>
#   <span class="line">⚙️ <b>Cross-validation</b> and <b>hyperparameter tuning</b> were applied to enhance model accuracy and generalization.</span>
#   <span class="line">📈 Based on evaluation metrics like Accuracy, Precision, Recall, F1-score, and ROC-AUC, the <b>K-Nearest Neighbors (KNN)</b> model performed the best with around <b>95% accuracy</b> on the test data.</span>
#   <span class="line">💡 Key predictors of heart disease included <b>ST Slope, Chest Pain Type,</b> and <b>Max Heart Rate</b>, showing strong correlation with target outcomes.</span>
#   <span class="line">🚀 The tuned <b>KNN model</b> was saved for potential deployment and can be applied to predict heart disease in new patient data.</span>
#   <span class="line">🏥 Overall, the project demonstrates that <b>machine learning</b> can effectively assist in <b>early detection and prevention</b> of heart disease.</span>
#   <span class="line">🏢 <i>This project is developed as part of the Machine Learning intern at <b>Unified Mentor Private Limited</b>.</i></span>
# </h3>
#
# <style>
#   #summary {
#     display: inline-block;
#     max-width: 950px;
#     text-align: left;
#     color: #ffffffff;
#     background: #000000ff;
#     border: 1px solid #000000ff;
#     padding: 20px 24px;
#     border-radius: 10px;
#     cursor: pointer;
#     line-height: 1.6;
#     font-family: system-ui, -apple-system, "Segoe UI", Roboto, "Helvetica Neue", Arial;
#     font-size: 0.98rem;
#     transition: transform 0.18s ease;
#     outline: none;
#   }
#
#   #summary:focus {
#     box-shadow: 0 0 0 4px rgba(0,0,0,0.04);
#   }
#
#   .line {
#     display: block;
#     opacity: 0.5;
#     transform: translateY(8px);
#     transition: opacity 360ms cubic-bezier(.2,.9,.2,1),
#                 transform 360ms cubic-bezier(.2,.9,.2,1);
#     margin-bottom: 0.6em;
#   }
#
#   #summary:hover .line,
#   #summary:focus .line {
#     opacity: 1;
#     transform: translateY(0);
#   }
#
#   #summary .line:nth-of-type(1) { transition-delay: 0.00s; }
#   #summary .line:nth-of-type(2) { transition-delay: 0.06s; }
#   #summary .line:nth-of-type(3) { transition-delay: 0.12s; }
#   #summary .line:nth-of-type(4) { transition-delay: 0.18s; }
#   #summary .line:nth-of-type(5) { transition-delay: 0.24s; }
#   #summary .line:nth-of-type(6) { transition-delay: 0.30s; }
#   #summary .line:nth-of-type(7) { transition-delay: 0.36s; }
#   #summary .line:nth-of-type(8) { transition-delay: 0.42s; }
#   #summary .line:nth-of-type(9) { transition-delay: 0.48s; }
# </style>

# %% [markdown]
# <h1 align="center">
#   <span>Thank</span>
#   <span>You</span>
#   <span>~</span>
#   <span>Happy</span>
#   <span>Coding</span>
#   <span>!</span>
#   <span></span>
# </h1>
#
# <style>
#     h1 {
#         text-align: center;
#         color: white;
#         padding: 50px;
#         border-radius: 12px;
#         display: inline-block;
#         background: linear-gradient(90deg, #5E4352, #BE3E82, #E43F6F, #F56476);
#         background-size: 200% 200%;
#         transition: background-position 0.6s ease, transform 0.4s ease;
#         cursor: pointer;
#     }
#
#     h1 span {
#         opacity: 0.3;
#         display: inline-block;
#         transform: translateY(20px);
#         transition: opacity 0.4s ease, transform 0.4s ease;
#     }
#
#     h1:hover {
#         background-position: 100% 0;
#         transform: scale(1.05);
#     }
#
#     /* Staggered reveal effect */
#     h1:hover span {
#         opacity: 1;
#         transform: translateY(0);
#     }
#
#     h1:hover span:nth-child(1) { transition-delay: 0s; }
#     h1:hover span:nth-child(2) { transition-delay: 0.2s; }
#     h1:hover span:nth-child(3) { transition-delay: 0.4s; }
#     h1:hover span:nth-child(4) { transition-delay: 0.6s; }
#     h1:hover span:nth-child(5) { transition-delay: 0.8s; }
#     h1:hover span:nth-child(6) { transition-delay: 1.0s; }
#     h1:hover span:nth-child(7) { transition-delay: 1.2s; }
# </style>
